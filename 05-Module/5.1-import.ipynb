# %%
from package import maths
maths.addition(5,4)
# sub(9,3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from package import addition
#       2 addition(5,4)
#       3 # sub(9,3)
#
# ImportError: cannot import name 'addition' from 'package' (/Users/santoshswami/Projects/AI-Python/05-Module/package/__init__.py)
